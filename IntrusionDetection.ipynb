# %% [markdown]
# # Import Statements

# %%
import csv
from statistics import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the intrusion.csv dataset

# %%
list1=[]
list2=[]
list3=[]
list4=[]

# 
# low = (1,1,1)  # black color for instrusion
# high = (1,0,0) # red color for intrusion

# opening the CSV file 
with open('intrusion.csv', mode ='r')as file: 
    
    # reading the CSV file 
    csvFile = csv.reader(file) 
    # Skip the first row which is just headers which can not be converted to float
    next(csvFile) 

    
  
    # spilt attributes and intrusion into their own lists by splitting up each line
    for line in csvFile: 
        list1.append(float(line[0])) # attribute 1
        list2.append(float(line[1])) # attribute 2
        list3.append(float(line[2])) # attribute 3 
        list4.append(int(line[3])) # intrusion

print(list1)
# Out:
# [2.157322350655286, 1.7116497069976015, -1.0627101085415402, -0.10034379400893068, 0.14507320791976652, 3.891701857020434, 3.4671814183882663, -0.4776599595673352, 0.5836352248519996, 1.0622489796857892, -0.10014250862103258, -1.1789686886476094, 0.1945030581289191, 0.5658890858911222, 1.9811243471651947, 0.7039591290233542, 0.06765744387140993, 0.997876290162847, 2.319638584236998, 0.08043040012932345, 3.851204169785587, 1.424623729232427, -0.22562821701796065, 0.47877098695783454, -1.2009424034590395, -0.7944268455416035, 1.5279513648821965, 1.190795089988336, 1.888258842656091, 1.1852951066549464, 1.100920153992941, -0.2482976259039067, 2.0977467844863518, 0.4087836053999907, 2.5531917577239094, 4.74582957876146, 1.196358597155563, 1.7671047138105753, 1.1196618957172266, 0.7066624687429511, -0.01687103161282444, -1.5539873507319681, 2.8769664894766023, 1.346149159195949, 0.9411488801288275, 1.8645786010125542, 0.5610587623027375, 1.038786350884647, -1.00454613252868, 2.33574603090
# ...

# %% [markdown]
# # Create a scatter plot (make sure the scatter plot has a legend, title, and x and y labels) using matplotlib.pyplot with:

# %% [markdown]
# ### Attribute 1 and Attribute 2 (colored by “Intrusion”)

# %%
# Create the plot 
scatter = plt.scatter(x=list1, y=list2, c=list4)

# Add plot labels 
plt.title("Attribute 1 VS Attribute 2 Colored by Intrusion")
plt.legend(*scatter.legend_elements(),loc='center left', bbox_to_anchor=(1, 0.5))
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("Attribute 1")
plt.ylabel("Attribute 2")

# Show the plot 
plt.gcf().set_size_inches((10, 10)) 
plt.show()

# %% [markdown]
# ### Attribute 2 and Attribute 3 (colored by “Intrusion”)

# %%
# Create the plot 
scatter = plt.scatter(x=list2, y=list3, c=list4)

# Add plot labels 
plt.title("Attribute 2 VS Attribute 3 Colored by Intrusion")
plt.legend(*scatter.legend_elements(),loc='center left', bbox_to_anchor=(1, 0.5))
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("Attribute 2")
plt.ylabel("Attribute 3")

# Show the plot 
plt.gcf().set_size_inches((10, 10)) 
plt.show()

# %% [markdown]
# # Split the data into train and test sets using sklearn

# %% [markdown]
# ### Imports

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %% [markdown]
# ### All Attributes

# %%
# nplist1 = np.array(list1)
# nplist2 = np.array(list2)


# Import the data
df = pd.read_csv('intrusion.csv')
print(df.shape)
  
# head of the data
print(df.head())
  
x = df[['Attribute1','Attribute2', 'Attribute3']]
y = df['Intrusion']

# ""Split the data into train(80%) and test(20%) sets""
# x_train and y_train sets are used for training and fitting the model
# x_test and y_test sets are used for testing the model if it’s predicting the right outputs/labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=105, shuffle=True)


# printing out train and test sets
print('x_train : ')
print(x_train.head())
print(x_train.shape)
print('')
print('x_test : ')
print(x_test.head())
print(x_test.shape)
print('')
print('y_train : ')
print(y_train.head())
print(y_train.shape)
print('')
print('y_test : ')
print(y_test.head())
print(y_test.shape)



# The -1 means we infer the length of the dimension
# x_train = x_train.reshape(-1, 1)
# x_test = x_test.reshape(-1, 1)

# # Linear Regression
# model = LinearRegression()
# # fit the regression model
# model.fit(x_train,y_train)

# # Prediction
# y_pred = model.predict(x_test)

# #Scatter Plot
# plt.scatter(x_train,y_train)
# plt.plot(x_test, y_pred, color='black', linewidth=2)
# Out:
# (10100, 4)
#    Attribute1  Attribute2  Attribute3  Intrusion
# 0    2.157322    1.922947    3.223735          0
# 1    1.711650    5.534262    1.519069          0
# 2   -1.062710    0.913824    0.715046          0
# 3   -0.100344    6.153463    2.250014          0
# 4    0.145073    6.553025    2.214019          0
# x_train :
#       Attribute1  Attribute2  Attribute3
# 1930    2.180815    7.185239    2.961671
# 4600    1.458446    3.789782    2.573856
# 1399   -0.846697    2.982160    3.416403
# 1283   -0.586740    3.878238    3.310551
# 539     1.383460    2.522033    2.135522
# (7575, 3)
#
# x_test :
#       Attribute1  Attribute2  Attribute3
# 164     0.364248    6.965775    1.465538
# 6806    1.656540    6.415989    1.438752
# 6517    0.339794    5.597681   -1.928161
# 2705    2.023330    7.246045    3.986815
# 8103    0.569380    3.278436   -0.250889
# (2525, 3)
#
# y_train :
# 1930    0
# 4600    0
# 1399    0
# 1283    0
# 539     0
# Name: Intrusion, dtype: int64
# (7575,)
# ...

# %% [markdown]
# # Train a Support Vector Classifier using the following kernels: Polynomial, Linear, and RBF
#
# svm means that the data is non-linearly separable
#
# We use Kernelized SVM for non-linearly separable data. Say, we have some non-linearly separable data in one dimension. We can transform this data into two dimensions and the data will become linearly separable in two dimensions
#
# Gamma : This parameter decides how far the influence of a single training example reaches during transformation, which in turn affects how tightly the decision boundaries end up surrounding points in the input space. If there is a small value of gamma, points farther apart are considered similar. So more points are grouped together and have smoother decision boundaries (maybe less accurate). Larger values of gamma cause points to be closer together (may cause overfitting).
#
# The ‘C’ parameter: This parameter controls the amount of regularization applied to the data. Large values of C mean low regularization which in turn causes the training data to fit very well (may cause overfitting). Lower values of C mean higher regularization which causes the model to be more tolerant of errors (may lead to lower accuracy).

# %% [markdown]
# ### Imports Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.svm import SVC # "Support vector classifier"
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Import the Dataset

# %%
# Read dataset to pandas dataframe
df = pd.read_csv('intrusion.csv')

# %% [markdown]
# ### Preprocessing

# %%
x = df.drop('Intrusion', axis=1)
y = df['Intrusion']

# %% [markdown]
# ### Train, Test, Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ## Polynomial
# The Polynomial kernel takes an additional parameter, ‘degree’ that controls the model’s complexity and computational cost of the transformation

# %%
model = SVC(kernel='poly', degree=5)
model.fit(x_train, y_train)
# Predictions on test data after training algorithm
y_pred = model.predict(x_test)
# Confusion Matrix and Classification Report
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()  # flattening the array and list expansion
print("# of True Negatives: ", tn)
print("# of False Positives: ", fp)
print("# of False Negatives: ", fn)
print("# of True Positives: ", tp)

print(classification_report(y_test, y_pred))
# Out:
# # of True Negatives:  1998
# # of False Positives:  0
# # of False Negatives:  7
# # of True Positives:  15
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1998
#            1       1.00      0.68      0.81        22
#
#     accuracy                           1.00      2020
#    macro avg       1.00      0.84      0.90      2020
# weighted avg       1.00      1.00      1.00      2020

# %% [markdown]
# ## Linear

# %%
model = SVC(kernel='linear')
model.fit(x_train, y_train)
# Predictions on test data after training algorithm
y_pred = model.predict(x_test)
# Confusion Matrix and Classification Report
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()  # flattening the array and list expansion
print("# of True Negatives: ", tn)
print("# of False Positives: ", fp)
print("# of False Negatives: ", fn)
print("# of True Positives: ", tp)

print(classification_report(y_test, y_pred))
# Out:
# # of True Negatives:  1996
# # of False Positives:  2
# # of False Negatives:  3
# # of True Positives:  19
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1998
#            1       0.90      0.86      0.88        22
#
#     accuracy                           1.00      2020
#    macro avg       0.95      0.93      0.94      2020
# weighted avg       1.00      1.00      1.00      2020

# %% [markdown]
# ## RBF (Radial Basis Function Kernel)
#
# The similarity between two points in the transformed feature space is an exponentially decaying function of the distance between the vectors and the original input space as shown below. RBF is the default kernel used in SVM.
#
# RBF is the default kernel used in SVM.

# %%
model = SVC(kernel='rbf')
model.fit(x_train, y_train)
# Predictions on test data after training algorithm
y_pred = model.predict(x_test)
# Confusion Matrix and Classification Report
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()  # flattening the array and list expansion
print("# of True Negatives: ", tn)
print("# of False Positives: ", fp)
print("# of False Negatives: ", fn)
print("# of True Positives: ", tp)

print(classification_report(y_test, y_pred))
# Out:
# # of True Negatives:  1996
# # of False Positives:  2
# # of False Negatives:  5
# # of True Positives:  17
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1998
#            1       0.89      0.77      0.83        22
#
#     accuracy                           1.00      2020
#    macro avg       0.95      0.89      0.91      2020
# weighted avg       1.00      1.00      1.00      2020

# %% [markdown]
# # Train Random Forest Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Read dataset to pandas dataframe
df = pd.read_csv('intrusion.csv')

x = df.drop('Intrusion', axis=1)
y = df['Intrusion']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, random_state=0)
model = RandomForestClassifier(n_estimators=1000)
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# printing out train and test sets
print('x_train : ')
print(xtrain.head())
print(xtrain.shape)
print('')
print('x_test : ')
print(xtest.head())
print(xtest.shape)
print('')
print('y_train : ')
print(ytrain.head())
print(ytrain.shape)
print('')
print('y_test : ')
print(ytest.head())
print(ytest.shape)
# Out:
# x_train :
#       Attribute1  Attribute2  Attribute3
# 2214   -0.173787    2.797303    0.557980
# 1569    2.783296    1.679023    2.308703
# 5031    2.183946    3.160260    2.586508
# 7827   -0.732027    2.917338    4.542519
# 8360    1.111763    2.090169    0.893140
# (7575, 3)
#
# x_test :
#       Attribute1  Attribute2  Attribute3
# 133     1.716883    4.129631   -0.990759
# 6837    0.393021    4.079947    2.365004
# 5996    1.518307    2.948261    3.035064
# 1376    1.020363    4.371449    2.487002
# 1095    3.908756    1.852504    2.276405
# (2525, 3)
#
# y_train :
# 2214    0
# 1569    0
# 5031    0
# 7827    0
# 8360    0
# Name: Intrusion, dtype: int64
# (7575,)
#
# y_test :
# 133     0
# 6837    0
# 5996    0
# 1376    0
# 1095    0
# Name: Intrusion, dtype: int64
# (2525,)

# %% [markdown]
# # Confusion Matrix & Classification Report of Random Forest Model

# %%
# Confusion Matrix and Classification Report
tn, fp, fn, tp = confusion_matrix(ytest, ypred).ravel()  # flattening the array and list expansion
print("# of True Negatives: ", tn)
print("# of False Positives: ", fp)
print("# of False Negatives: ", fn)
print("# of True Positives: ", tp)

print(classification_report(ytest, ypred))
# Out:
# # of True Negatives:  2504
# # of False Positives:  0
# # of False Negatives:  5
# # of True Positives:  16
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2504
#            1       1.00      0.76      0.86        21
#
#     accuracy                           1.00      2525
#    macro avg       1.00      0.88      0.93      2525
# weighted avg       1.00      1.00      1.00      2525
